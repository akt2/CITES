# %%
import pandas as pd

# %%
url = 'https://awionline.org/content/list-endangered-species'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                           Common Name  \
#  0                                                Addax
#  1                                        Anoa, lowland
#  2                                       Anoa, mountain
#  3                                Antelope, giant sable
#  4                                    Antelope, Tibetan
#  5    Argali [All populations except Kyrgyzstan, Mon...
#  6        Argali [Kyrgyzstan, Mongolia, and Tajikistan]
#  7                                     Armadillo, giant
#  8                                Armadillo, pink fairy
#  9                                    Ass, African wild
#  10                                     Ass, Asian wild
#  11                                               Avahi
#  12                                             Aye-aye
#  13                                            Babirusa
#  14                                      Baboon, gelada
#  15                                   Bandicoot, barred
# ...

# %%
type(tables)
# Out:
# list

# %%
df = tables[0]
df.columns = ['Common Name', 'Scientific Name', 'Status']
df.head()
# Out:
#              Common Name            Scientific Name      Status
# 0                  Addax        Addax nasomaculatus  Endangered
# 1          Anoa, lowland     Bubalus depressicornis  Endangered
# 2         Anoa, mountain           Bubalus quarlesi  Endangered
# 3  Antelope, giant sable  Hippotragus niger variani  Endangered
# 4      Antelope, Tibetan       Panthalops hodgsonii  Endangered

# %%
df = df.iloc[2:]
df.head()
# Out:
#                                          Common Name  \
# 2                                     Anoa, mountain
# 3                              Antelope, giant sable
# 4                                  Antelope, Tibetan
# 5  Argali [All populations except Kyrgyzstan, Mon...
# 6      Argali [Kyrgyzstan, Mongolia, and Tajikistan]
#
#              Scientific Name      Status
# 2           Bubalus quarlesi  Endangered
# 3  Hippotragus niger variani  Endangered
# 4       Panthalops hodgsonii  Endangered
# 5                 Ovis ammon  Endangered
# 6                 Ovis ammon  Threatened

# %%
df.set_index('Scientific Name', inplace=True)
df.head()
# Out:
#                                                                  Common Name  \
# Scientific Name
# Bubalus quarlesi                                              Anoa, mountain
# Hippotragus niger variani                              Antelope, giant sable
# Panthalops hodgsonii                                       Antelope, Tibetan
# Ovis ammon                 Argali [All populations except Kyrgyzstan, Mon...
# Ovis ammon                     Argali [Kyrgyzstan, Mongolia, and Tajikistan]
#
#                                Status
# Scientific Name
# Bubalus quarlesi           Endangered
# Hippotragus niger variani  Endangered
# Panthalops hodgsonii       Endangered
# Ovis ammon                 Endangered
# Ovis ammon                 Threatened

# %%
df.loc['Loxodonta africana']
# Out:
# Common Name    Elephant, African
# Status                Threatened
# Name: Loxodonta africana, dtype: object
